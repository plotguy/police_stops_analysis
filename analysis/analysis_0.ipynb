# %%
# Preliminary Data Analysis for Police Stops Data

# %%
import pandas as pd

# %%
data_path = '../data/'
sc_data = 'sc_statewide_2020_04_01.csv'

# %%
df = pd.read_csv(data_path + sc_data, nrows=100000)

# %%
df.head()
# Out:
#    raw_row_number        date       location       lat       lng  \
# 0               1  2006-02-12   US Prmary 17  33.19950 -79.39269
# 1               2  2007-10-17  SC Primary 86       NaN       NaN
# 2               3  2007-03-20  SC Primary 11       NaN       NaN
# 3               4  2007-07-02   US Prmary 29       NaN       NaN
# 4               5  2008-11-08  Interstate 20  34.20619 -79.99261
#
#           county_name  subject_age subject_race subject_sex officer_id_hash  \
# 0   Georgetown County         33.0        white        male      cebc4b3995
# 1     Anderson County         17.0        white        male      ef3225d61e
# 2   Greenville County         68.0        white        male      808e789e5f
# 3  Spartanburg County         27.0        black      female      5df6d7974a
# 4   Darlington County         29.0        white        male      35d5dd2f85
#
#    ...  search_person search_vehicle     reason_for_stop raw_contact_type  \
# 0  ...          False          False     Radar Triggered         Citation
# 1  ...          False          False  Violation Observed   Public Contact
# 2  ...          False          False  Violation Observed         Citation
# 3  ...          False          False     Radar Triggered         Citation
# 4  ...          False          False  Violation Observed         Citation
#
#   raw_sex  raw_race  raw_sectionnum  \
# 0       M     White       ---------
# 1       M     White             NaN
# 2       M     White       ---------
# 3       F     Black       ---------
# 4       M     White       ---------
#
#                                      raw_offensecode raw_contrabanddesc  \
# 0                                   Other Violations                NaN
# 1                                                NaN                NaN
# 2  Speeding or Too Fast For Conditions (-- m.p.h....                NaN
# 3  Speeding or Too Fast For Conditions (----- m.p...                NaN
# 4  Speeding or Too Fast For Conditions (----- m.p...                NaN
#
#   raw_officer_race
# 0            White
# 1            White
# 2            White
# 3            White
# 4            Black
#
# [5 rows x 34 columns]
